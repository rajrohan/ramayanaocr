# %%
# https://www.kaggle.com/kernels/scriptcontent/11511967/notebook

import string
import numpy as np
import pandas as pd
# from IPython.display import display
from tqdm import tqdm
from collections import Counter
import ast
import re
from pprint import pprint

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# import matplotlib.mlab as mlab
import seaborn as sb

from sklearn.feature_extraction.text import CountVectorizer,TfidfTransformer
# from textblob import TextBlob
import scipy.stats as stats

from sklearn.decomposition import TruncatedSVD
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.manifold import TSNE

import nltk
from nltk.tag import tnt
from nltk.corpus import stopwords
from nltk.corpus import indian
from nltk.tokenize import word_tokenize,sent_tokenize

import gensim
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
import gensim.corpora as corpora
from gensim.summarization import summarize
from gensim.test.utils import datapath

import stanfordnlp
import networkx as nx
import math

import warnings
warnings.filterwarnings("ignore")

# from bokeh.plotting import figure, output_file, show
# from bokeh.models import Label
# from bokeh.io import output_notebook
# output_notebook()

# %matplotlib inline

# %%
nlp = stanfordnlp.Pipeline ( lang = 'hi' )
# Out:
# Use device: cpu
# ---
# Loading: tokenize
# With settings:
# {'model_path': '/Users/rohanraj/stanfordnlp_resources/hi_hdtb_models/hi_hdtb_tokenizer.pt', 'lang': 'hi', 'shorthand': 'hi_hdtb', 'mode': 'predict'}
# ---
# Loading: pos
# With settings:
# {'model_path': '/Users/rohanraj/stanfordnlp_resources/hi_hdtb_models/hi_hdtb_tagger.pt', 'pretrain_path': '/Users/rohanraj/stanfordnlp_resources/hi_hdtb_models/hi_hdtb.pretrain.pt', 'lang': 'hi', 'shorthand': 'hi_hdtb', 'mode': 'predict'}
# ---
# Loading: lemma
# With settings:
# {'model_path': '/Users/rohanraj/stanfordnlp_resources/hi_hdtb_models/hi_hdtb_lemmatizer.pt', 'lang': 'hi', 'shorthand': 'hi_hdtb', 'mode': 'predict'}
# Building an attentional Seq2Seq model...
# Using a Bi-LSTM encoder
# Using soft attention for LSTM.
# Finetune all embeddings.
# [Running seq2seq lemmatizer with edit classifier]
# ---
# Loading: depparse
# With settings:
# {'model_path': '/Users/rohanraj/stanfordnlp_resources/hi_hdtb_models/hi_hdtb_parser.pt', 'pretrain_path': '/Users/rohanraj/stanfordnlp_resources/hi_hdtb_models/hi_hdtb.pretrain.pt', 'lang': 'hi', 'shorthand': 'hi_hdtb', 'mode': 'predict'}
# Done loading processors!
# ---

# %%
datafile = '../data/hindi.txt'
with open(datafile,'r',encoding='utf-8') as f:
    text = f.read()
    text = text.split("॥")

# %%
text_sentence = []
i = 0
for word in tqdm(text):
#     print(i,word)
    if re.findall("^\s?\d+\s?",word):
        continue
    else:   
        text_sentence.append(word)
# Out:
# 100%|██████████| 1290/1290 [00:00<00:00, 427145.51it/s]

# %%
text_sentence[0:2]
# Out:
# [' वानर हनुमान सीमा के देखने की उत्कण्ठा येसूयास्त की प्रतीक्षा करता भया ',
#  ' घ४-९) सीता को रावण के भन्तापुर में ढूंढना : वह महावीर्य महान हृदय पाछा वानर श्रेष्ठ रात के समय अद्वार से कोट को फांद कर का में प्रविष्ट हृया ']

# %%
len(text_sentence) #total sentences
# Out:
# 667

# %%
# hindi stopwords
stop_words_df = pd.read_csv("../data/stopwords.txt", header = None)
stop_words = list(set(stop_words_df.values.reshape(1,-1).tolist()[0]))
stop_words.extend(["।", "।।", ")", "(", ",",'"',"हे", "हो", 'में','से','COMMA'])

# %%
len(stop_words)
# Out:
# 723

# %%
stop_words[:2]
# Out:
# ['सकती', 'बारे']

# %%
def create_str_from_list(original_read_text):
    prepared_text = ""
    for line in original_read_text:
        line = line.split()
#       print(line)
        tmp_line = " ".join(line)
        prepared_text += " \n"+tmp_line
    return prepared_text

# %%
str_text = create_str_from_list(text_sentence)

# %%
str_text[0:2500]
# Out:
# ' \nवानर हनुमान सीमा के देखने की उत्कण्ठा येसूयास्त की प्रतीक्षा करता भया \nघ४-९) सीता को रावण के भन्तापुर में ढूंढना : वह महावीर्य महान हृदय पाछा वानर श्रेष्ठ रात के समय अद्वार से कोट को फांद कर का में प्रविष्ट हृया \nधानरराज के उस हितैषी ने लंका नगरी में प्रवेश करके मानों अपना बायां पाओं शत्रु के सिर पर रख दिया \nउस समय सुन्दर \'सब ओर से सजे हुए श्वेत मेघ के तुल्य राक्षसों के जो पद्माकार, स्वस्तिकाकार, और वर्धमान घर है, उन से इंका जगमन. कर रही थी, राधा के अर्थ वह श्रीमान् घूमता हुमा उसे देखता भया और आनन्दित होता भया ।। ३, ४ \nएक भवन से दूसरे भवन को जाते हुए उस वानरश्रेष्ठ ने वहाँ र विविध भाकृति और रूपों वाले भवन देखे \nवहाँ राक्षसों के घरों में उसने अप "करते हुओं के मन्त्र मुने और स्वाध्याय में रत राक्षसों को देखा \nराक्षसों के घर से घर और बगीचों को देखता हुआ बेधड़क यह महलों के पास घूमा \nतव पवनपुत्र हनुमान ने यह भवन श्रेष्ठ देखा, जो राक्षसपति का भवन है, और बहुत महलों से भरपूर है \nविशाल नेत्रोंवाली वैदेही सीता को ढूंढता हुआ शत्रुनों के मारनेवाला, हनुमान उसके चारों ओर घूमा ।। ९ \nतब वह उस सुन्दर पड़ी माला की ओर मस्थित हुआ, जो उत्तम स्त्री की तरह रावण की बड़ी पारी थी \nजिमकी सीदियों में माणेयां जड़ी हुई हैं, जो सोने के झरोकों से भूपित हैं, सङ्गमर्मर का फर्श है, और बीच २ में दान्त का काम किया हुआ है \nजो सम, सीधे, बड़े कंचे पूरे २ मजे हुए स्तम्भों मे मानों आते ऊँचे पलों से छौ की ओर प्रस्थित हुई है \nसोंचम गलीचा जिसमें पिछा हुआ है, राक्षों के अधिपति से सेवित है, मन को प्रसन्न करने वाली और शरीर की कान्ति को बढ़ाने वाली है।। १३ \nदीपकों के प्रकाश से, रावण के तेज से, और भूषणों की चमक मे, पानों जलती हुई प्रतीत होती है। \nउस शाला में देखते हुए इनुमान् ने रत्नों मे भाषेत एक दिव्य विलोरी शपनानन ( बैठने मोने का एला ) देखा \nओर शराब पीकर बन्द हुए, श्रीद चमकते हुए पलङ्ग -. पर लेटे हुए राक्षसाधिपति को उस महारानर ने देखा \nससके पास आकर बड़ा गीवन इा अत्यन्त डरे हुए की तरह पीछे-इट गया, और प्यारी खियों वाले उस राक्षसपति के घर. में बस वानर यूयपति ने चन्द्र तुल्य मुखवाली, सुन्दर कुण्डल पहने हुई, ताजे घुषषों की पालाएं और भूषणोंवाली पनियों को देसा \nउन में से एकान्त स्थिव एक गुभ शय्या के ऊपर लेटी हुई रुपवती उम ने एक खो देखी \nजो अपनी शोभा से मानों उस उत्तम भवन को शोभायमान करती थी, बद्द मन्दोदरी थी, जोकि सुन्दर रूपवती वहां लेटी हुई थी \nमहाबाहु पवनसुत ने उस भूषित स्त्री को देखकर उमके रूप यौवन की सम्पदा से रूपाल किया, कि कदाचित यह सीता हो \nय०१०-११) राधण के अन्तःपुर में सीता का न पाना पर उसी समय उस रूपाळ को पटाकर, स्थित हुा महा . घानर सीता के विषय भरा विचार करता भया \nकि राम से वियुक्त हुई वह मुन्दरीन सो सक्ती है, न भोग रती है, न अलङ्कार कर सक्ती है, न पान सेवन कर सक्ती है \nनि:सन्देह यह कोई और है, ऐसा'

# %%
summarize(str_text[0:2500])
# Out:
# "घ४-९) सीता को रावण के भन्तापुर में ढूंढना : वह महावीर्य महान हृदय पाछा वानर श्रेष्ठ रात के समय अद्वार से कोट को फांद कर का में प्रविष्ट हृया \nउस समय सुन्दर 'सब ओर से सजे हुए श्वेत मेघ के तुल्य राक्षसों के जो पद्माकार, स्वस्तिकाकार, और वर्धमान घर है, उन से इंका जगमन.\nराक्षसों के घर से घर और बगीचों को देखता हुआ बेधड़क यह महलों के पास घूमा \nतब वह उस सुन्दर पड़ी माला की ओर मस्थित हुआ, जो उत्तम स्त्री की तरह रावण की बड़ी पारी थी \nमें बस वानर यूयपति ने चन्द्र तुल्य मुखवाली, सुन्दर कुण्डल पहने हुई, ताजे घुषषों की पालाएं और भूषणोंवाली पनियों को देसा "

# %%
len(str_text)
# Out:
# 68718

# %%
df = pd.DataFrame()

# %%
def summarization(str_text):
    startflag = 0
    endflag = 2500
    parsed_text = {'text':[], 'title':[]}
    for summary in range(int(len(str_text)/endflag)):
        summarization_block = summarize(str_text[startflag:endflag])
        parsed_text['text'].append(str_text[startflag:endflag])
        parsed_text['title'].append(summarization_block)
        startflag +=2500
        endflag +=2500
    return pd.DataFrame(parsed_text)

# %%
df = summarization(str_text)
df.shape
# Out:
# (27, 2)

# %%
df.to_csv('input_abstarct_summary.csv')

# %% [markdown]
# ### Alternative Summarization from Gensim

# %%
def textrankTfIdf(document):
    # sentence_tokenizer = PunktSentenceTokenizer()
    # sentences = sentence_tokenizer.tokenize(document, 'hindi')

    sentences = document
    bow_matrix = CountVectorizer().fit_transform(sentences)
    # normalized = TfidfTransformer(norm='l2', use_idf=True, use_bm25idf=True, smooth_idf=True,
    #              delta_idf=False, sublinear_tf=False, bm25_tf=True).fit_transform(bow_matrix)

    normalized = TfidfTransformer().fit_transform(bow_matrix)
    similarity_graph = normalized * normalized.T

    nx_graph = nx.from_scipy_sparse_matrix(similarity_graph)
    scores = nx.pagerank(nx_graph)
    return sorted(((scores[i], s) for i, s in enumerate(sentences)),
                  reverse=True)
def orderSentences(rankedList, data, initSentences):
    index = ['']*len(data)
    # print(rankedList)
    for eachRanked in rankedList[0:int(math.ceil(0.4*len(rankedList)))]:
        sen = eachRanked[1]
        index[data.index(sen)] = initSentences[data.index(sen)]
        # print(data.index(sen))
    return index

# %%
int(len(text_sentence)/25)
# Out:
# 26

# %%
def alternate_summarization(text_sentence):
    startflag = 0
    endflag = 25
    parsed_text = {'text':[], 'alt_title':[]}
    for summary in range(int(len(text_sentence)/endflag)):
        rankedSentences = textrankTfIdf(text_sentence[startflag:endflag])
        orderedsentences = orderSentences(rankedSentences, text_sentence[startflag:endflag], text_sentence[startflag:endflag])
        for ordered in orderedsentences:
            if ordered != "":
                parsed_text['alt_title'].append(ordered)
        parsed_text['text'].append(text_sentence[startflag:endflag])
        startflag +=25
        endflag +=25
    return pd.DataFrame(parsed_text)

# %%
df2 = alternate_summarization(text_sentence)
# Out:
# 0  वानर हनुमान सीमा के देखने की उत्कण्ठा येसूयास्त की प्रतीक्षा करता भया
# 0  उस समय सुन्दर 'सब ओर से सजे हुए श्वेत मेघ के तुल्य राक्षसों के जो पद्माकार, स्वस्तिकाकार, और वर्धमान घर है, उन से इंका जगमन. कर रही थी, राधा के अर्थ वह श्रीमान् घूमता हुमा उसे देखता भया और आनन्दित होता भया ।। ३, ४
# 0  एक भवन से दूसरे भवन को जाते हुए उस वानरश्रेष्ठ ने वहाँ र विविध भाकृति और रूपों वाले भवन देखे
# 0  वहाँ राक्षसों के घरों में उसने अप "करते हुओं के मन्त्र मुने और स्वाध्याय में रत राक्षसों को देखा
# 0  तब वह उस सुन्दर पड़ी माला की ओर मस्थित हुआ, जो उत्तम स्त्री की तरह रावण की बड़ी पारी थी
# 0  ओर शराब पीकर बन्द हुए, श्रीद चमकते हुए पलङ्ग -. पर लेटे हुए राक्षसाधिपति को उस महारानर ने देखा
# 0  ससके पास आकर बड़ा गीवन इा अत्यन्त डरे हुए की तरह पीछे-इट गया, और प्यारी खियों वाले उस राक्षसपति के घर. में बस वानर यूयपति ने चन्द्र तुल्य मुखवाली, सुन्दर कुण्डल पहने हुई, ताजे घुषषों की पालाएं और भूषणोंवाली पनियों को देसा
# 0  जो अपनी शोभा से मानों उस उत्तम भवन को शोभायमान करती थी, बद्द मन्दोदरी थी, जोकि सुन्दर रूपवती वहां लेटी हुई थी
# 0  य०१०-११) राधण के अन्तःपुर में सीता का न पाना पर उसी समय उस रूपाळ को पटाकर, स्थित हुा महा . घानर सीता के विषय भरा विचार करता भया
# 0  नि:सन्देह यह कोई और है, ऐसा निश्चय करके फिर वह विचरने लगा, " इसमकार रावण का सारा अन्तःपुर( रनिवास ) उस महातेजस्वी वानर ने पूरी तरह देखा, पर जानकी को नहीं देखा
# 25 निःमन्दह मैंन चिश्वस्त लेटी हुई रावण की सव स्त्रिये देखी है, पर मेरे मन में कोई विकार उत्पन्न नहीं हुशा है
# 25  शुभ अशुभ्र अवस्थाओं में मन ही सार इन्द्रियों की प्रकृति में हेतु है, और यह मेरा ठीक टिका हुआ है (विस्कुल नहीं होला है )
# 25  सो मैंने शुद्ध मन से रावण का पारा अन्तःपुर ढूंढ लिया, पर जानकी नहीं दीखती
# 25  जब उस वीर वानर ने वहां और ही सुन्दर खिया को देखा, किन्तु सीता को न देखा, तब वह वहां से निकलकर चलने को तय्यार हुआ
# 25  ) सीता के न मिलन से हनुमान की उदासी सब बद महावानर राम की इस प्यारी को न देखता हुआ सोचने लगा, निमन्देह मैथिली सीता जीती नहीं है, जिससे मुझे हूंढने हुए कहीं नहीं दीखती है
# 25  मैंने सारा अन्तापुर देख लिया, रावण की स्त्रिये देखली, पतिव्रता सीवा नहीं देखी, सारा परिश्रम व्यर्थ गया। जब मैं जाऊंगा, सो सारेवानर मिलकर मुझे क्या करेंगे, वीर वहां जाकर तूने क्या किया मो कहो
# 25  और मैं उस जनकमुता को न देखकर क्या कहूंगा, और मुद्ध जाम्बवान और वह अशा मुझे क्या कडेगा
# 25  यह सोचकर वह फिर हूँढने लगा, और बह मावानर एक अवकाश में फिस!! ८.
# 25  संगर (१० १३ हनुमान के अनेक विध विचार मुहूर्तभर यह सोचकर और मन से निश्चय करके वह महा तेजस्वी उस मन्दिर के कोट को फांद गया
# 25  वह वानर वहां विचरता हुआ मनोरम मणिभूमिप, चान्दी की सी भूमि, और सुनहरी मामयें देखता भया
# 50  तब उस वानर ने सारे जगह में सुहावना एक पर्वत देखा, जो चाटियों में सब ओर से घिरा हुआ विचित्रकूट नामी था
# 50  वड़ महादानर पत्तों से पूर्ण उस वोक्षम पर चढ़ गया, कि यहां से मैं राम के देखने की लालसा गळी वैदेही को देखूगा
# 50  और नद नदियों का पति श्रीमान सागर मैंने लेघा है, इस विशालनत्रा के हेतु मैंने यह सारी पुरी ढूंढ़ी है
# 50  इसके लिये यदि राम समुद्र पर्यन्त सारी पृथिवी को और जगत् को भी उलट दे, तो युक्त है, यह मेरी मति है
# 50  से यह सुवर्ण तुल्य रङ्गवाली, नित्य हंसती हुई बोलने पाली इस तीन दुःख को सह रही है, जोकि अनयों की योग्या नहीं है
# 50  न यह इन राक्षसियों को देखती है,न पुष्प फलों चाले पक्षों को,किन्तु एक ही जगह दिल को टिकाकर केवल राम को ही देख रही है
# 50  पति स्त्री को भूषण से भी बढ़कर शोभा देनेवाला होता है। यह बम से रहित हुई शोभा के योग्य भी शोभा नहीं पाती है
# 50  राम बड़ा दुष्कर कय कर रहे हैं, जो इसमे हीन हुए अपने देह को धारते हैं, दुःख से फट नहीं जाते
# 50  इस काले बालों. वाली पद्मपत्र तुल्य नेत्रोंवाली, सुख के योम्पा को पुखिया देख कर मेरा भी हृदय दुःखित बारहा है।
# 50  इत्यादि बातों को देखकर यह सीता है, इसमकार निश्चयवाला बलबाला, वेगवाला, वानरों उस वृक्ष पर बैठ गया
# 75  , १८) प्रभात का समय और रावण का अशोकवनिका में आना तत्र कुमुद खण्ड के तुल्य निर्मल चन्द्र, नीले जल पर हंस की तरह निर्मल आकाश पर उदय हुभा
# 75  उस समय मङ्गक बाओं और कानों के प्यारे शब्दों से महाबाहु महाबड़ी रावण जागा
# 75  पहाने जम्बी महावानर ने उस बेजात्री को देखा, तब वह बुद्धिमान् वानर " यह महावाहु रावण है" ऐसा सोचकर शाखाओं के अन्दर पत्नों में छिय गया ।। ११, १२
# 75  च०१५, २०) रावण को देखकर सीता का मय मौर रावण का प्रेम दिखलाना तब राक्षसाधिपति रावण को देखते ही वरारोहा सीता मवल वायु में कदली की तरह कांप उठी
# 75  रानों से पेट को और भुजाधों से स्तनों को हांप कर यह विशालनेत्रा चरबणिनी रोती ई सिमटकर बैठ गई
# 75  रावण ने राक्षसीगणों से रक्षा की हुई, दीन, दुःख से पीड़ित सीता को समुद्र में टूटी हुई नौकावत देखा ।। ३ ।। खाली भूमि पर बैठी हुई, तीक्ष्ण प्रवाही (मानों रावण के षध के लिए तीक्ष्ण व्रत करती ई) कटकर भूमि' पर गिरी वनस्पति की शाखा की सरह
# 75  मैले रूपी भूषण से लिरते हुए अङ्गोवाली, भूपों के योग्या, पर भूषणों में शहेत कीचर से लिबड़ी कमलिनीकी तरह भासती है और नहीं भासती
# 75  मुखली हुई रोती हुई अकेकी ध्यान शोक परायण हुई दुःख का अन्त न देखती हुई राम के अनुनत रमणी
# 75  मुझे देख कर हे हाथी के मूह के तुल्प रानों वाळी २ स्तन भीर उदर को छिपानी हुई मानों भय मे अपने पाप को अदृश्य कर रही
# 75  दे देवि ! इसमें तुझे भय नहीं करना चाहिये, हे पारी मेरे ऊपर विश्वास कर, पूरा २ प्रेम कर, इमरद पोकपरायण न हो
# 100  मैं . जानता है, कि तुझ उत्पन्न बार के रूप के बनाने वाले विश्वकर्मा ने रूप बनाना छोड़ दिया है, डे शुभ दर्शनवाली सेरे तुल्य और रूप की उपमा नाँ है
# 100  सारे लोकों से पल से हर कर जो मैं रत्न लाचा हूं, हे भरु तुझे यह सारे और गज्य देता हूं
# 100  हे भीरु यथारूचि भोगों को भोग, और पानकर. और यथारुचि पृथिवी और धन का दान
# 100   व० २६) सीता का पवित्र उत्तर जम रौद्र राक्षस के वचन का सुनकर रोसी दुई कांपती हुई, बेचारी दुखिया सीता ।।पनियता शुद्ध इंधीवाली परारोहा पति काही चिन्तन करती हुई मध्य में तुण रखकर (दुष्ट अभिप्राय चाके में माक्षाव बात करना भी प प जानकर उत्तर देवी भई
# 100 मैं पतिव्रता महान कुल में उत्पन्न हुई श्रीर महा कुल को पात 'हुई ऐसा निन्दित अकार्य नीं करूंगी
# 100  क्या यह ले पुरुषों नहीं. वा. भलों के पीछे नहीं चलता है, जैसा कि यह सरी एलटी बुद्धि सदाचार से उलटी है
# 100  अमितेन्द्रिय, अनीति में रत, राजा को पाकर समृदिशाली भी नगर और देश नष्ट होजाते हैं
# 100  मैं ऐश्वर्य, धा धन से लुभाई नहीं जासक्ती, मैं राघव से इस तरह अभिन्न हूं, जैसे मूर्प से प्रभा ।। १० ।। उस लोकनाथ की पूजित भुजा को सिर के नीचे रखकर अब कैसे किसी दूसरे की भुजा को सिर के नीचे रखुगी
# 100  में उसी पृथिवीपति के योग्य भार्या है, जो विषा व्रतस्वात और साधनों के जानने वाले ब्राह्मण के ही योग्य होती है
# 100  राक्षण सुन दुखिया को राम के साथ मिला दे, यही भला है, इस से अन्यथा करता हुआ तू परम आपद को प्राप्त होगा ।।१३
# 125  यह देदा काम । मनुष्यों का जिसमें बच जाता है, उस जन पर दया और मेह । पत्रम होजाता है। इसकारण से हे वरानने मैं तुझे मारवा नहीं हूं. जो वध के योग्य, अपमान के योग्य और मिथ्यात्यागाविषय त्याग) में रस है । जो २ कठोर वाक्य तु मुझे कहती है,उनर में है मैथिलि तेरा दारुण क्ध युक्त है
# 125  सक्षम्पले रावण सीता को ऐसे कहकर फिर क्रोध और जोश से भरा हुआ पचन बोला
# 125  क्या इस नगर में कोई भी पुरुष तरी भलाई में स्थिर नहीं, जो तुझ इस निन्दिय कर्म से रोकता नहीं है
# 125  यह तरे काले कैरे विकृत क्रूर नेत्र हे अन.ये मेरी ओर देखते हुए के थिली पर क्यों नहीं गिर पड़वे ।। १४ । उत धर्मात्मा की पत्नी दश ध.की स्तुपा मुझको ऐनी बात करते हुए दे पापी सरी जिला क्यों नहीं फट जाती
# 125 मुझे धर्मास्मा राम की आशा नहीं और आप को बचाना है, इसलिये हे रावण मैं तुझे अपने (पातिप्रस के) तेजस भस्म नहीं करती है, यद्यपि त् भस्म के योग्य है
# 125  वण का सीना पर क्रोध सीता के वचन को सुनकर साक्षसपति रावण क्रूर मेवों को मोड़कर जानकी की ओर देखता भया
# 125  कोष से लाल हुए मेवों वाला भुजङ्ग की सरह सांस लेता हुआ रावण पैदेही सीता की और देखता हुआ बोला
# 125  शत्रुओं के रुलाने वाला, राजा-रावण यैथिली को यह कहकर फिर भयङ्कर दर्शनवाली, राक्षसियों की और देखता भया
# 125  वार २ वह आज्ञा देकर काम क्रोध से भरे हुए मन चाळा राक्षसन्द्र जानकी के प्रति गर्जा
# 125  उसी समय पान्यमालिनी राक्षसी निकट पहुंचकर आलिअन करके रावण मे यह वचन बोकी
# 150 ई सीते बहुमूल्य शय्याओं से युक्त सबलोगों के मन को लुभानेवाले अन्तःपुर में वास तू क्यों पसन्द नहीं करती बिलोकी के ऐश्वर्य को भोगने वाले रामसेमा रावण को भर्ता चनाकार मुख पूर्वक निहार कर
# 150  तुप सर इकही होकर पा को कोक निन्दिव वाक्य कहती हो, यह पाप भरा वाक्य मेरे मन में जगह नी पकड़ सका है
# 150  मानुपी राक्षम की भार्या नहीं हो सक्ती पेशक सब मिलकर मुझे खाजाओ, पर तुम्हारी बात नहीं मानेगी
# 150  दीन वा राज्यहीन है, जो मेरा भा है, वह मेरा गुरु है, उस पर सदा अनुरक्त है, जैसे सूर्य पर सुघर्षला
# 150  उस शीशम के वृक्ष पर चुपचाप छिपा श्रा इनुमान, वानर सीता को झिड़कती हुई राक्षसियों को सुनता भया
# 150  वह नेत्रों के जक के पहने से अपने विपुक स्तनों को स्नान कराती, और सोचती हुई, तब शोक का अन्त नहीं पाती।
# 150  खिया सुन्दरी " हा सम" का लक्ष्मण, हा परी सास कोरपा, हा पुमित्रा, पापार २ कहती भई । विद्वानों ने यह कहावत ठीक कही है, किरिना काळ के स्त्री पा पुरुष को प्रत्यु दुर्बम है | जब कि में इन क्रूर राक्षसियों से यहां पीड़ित हो राप में वियुक्त हो दुखिपा होकर मुईत मी भीती हूं 1
# 150  पड़े शोक से घिरी हुई, में जीवन त्यागना चाहती है. इन राजसियों से रक्षा की दुई में राम को नहीं पापकूली
# 150  विज्ञार है मनुष्यता को और विकार है पराधीनता को, जिम में कि अपनी इच्छा से जीवन भी नही फामा आरक्ता ३१२
# 150  मैं राक्षस रावण को चाएं पाओं से भी नहीं छूगी, क्या फिर में उसे कामना कर
# 175  वह भरत का पड़ा भाई गम मुमो जीती हुई नहीं जानता है, वह जानते तो क्या. पृथिवी में ढूंद भाळ न करते
# 175  अथवा निःसन्देह मेरे ही शोक से वह वीर लक्ष्मण का बड़ा भाई पृथिवी पर देह को याग कर यहाँ मे देवलोक को चला गया
# 175  जिसको पड़त २ वानर सारी दिशाओं में ढूंढ रहे हैं, बद्द यह ने पाकी है
# 175  पेरे वहां चले जाने पर यह यशस्विनी राजपुषी मानकी परित्राण न देखती हुई जीवन को साग देगी
# 175  इसी सविशेष यदि में इसे तसल्ली न दे सका, तो बिस्कुल पन्दे। नहीं, कि यह जीवन याग देनी
# 175  कैमे पद परे वाक्य को मुने, और हरे नाँ, यह सोचकर पतिमान हनुपान ने या विचार किया
# 175  मुखदायी कर्मोंचाळे उसके बन्धु राम का कीर्तन करता हुआ इसको डरने मे बचाऊंगा, क्योंकि इस का चित्त उसी वन्धु में लग रहा ई
# 175  मीठी वाणी पाळता हुभा (राम के ) मारे (कार्य) सुनाऊंगा, जिससे सीता विश्वास करेगी वैसे सब कुछ कहूँगा ।। १० ।। सगै १८ (३०३१) हनुमान् का सम के पुण वर्णन इस प्रकार यह महामात अनेक प्रकार की चिन्ता करके सीता को सुनाई देते स्वर में मधुर वाक्य नोळा
# 175  वह सची प्रतिज्ञापाले उस वृद्ध पिता के वचन से भार्या और भाई समेत वन को रवाना हुआ
# 175  वन में सुग्रीव नाप वानर को मित्र बनाता मया, दष वह शधुओं के किले जीसने वाला राम मालि को मार कर
# 200  वानरों का राज्य महात्मा अग्रीय को देता भया, सुग्रीव से आशा दिये हुए, कायरूपी अनेक वानर उस देषी को दूरते हुए सप दिशाओं मैं गये, और मैं सम्पाति के कहने सर्म १५] से मी योजन कम्प्रे ।। १०,११
# 200  राम से पैने बह सुनी थी, वह यह मैंने पानी , इतना वचन कहकर वह वानरश्रेष्ठ चुप होगया
# 200  ,३४) पनुमार का सीता के समीप माना और सौता का सन्देह तच यह उस वृक्ष ये जरूर कर पास श्रामणाम करके पवनपुत्र हनुमान सिर पर हाय बांधकर मधुर वाणी से उस सीता से बोला
# 200  राम के सन्देश से हे देवि ! मैं तेरे पास दृत आया हूं, से पैदेहि ! राम कुशल से हैं, और उन्होंने तुझ कुमाक कहा है
# 200  शोक से सपी हुई सीता के वचन को पुनकर पवनपुत्र हनुमान उनके समीप २ होता गया
# 200   ७ पर ज्यों २ हनुमान सीता के समीप आता है त्यों २ (रावण से हरी हुई ) सीता उसके रावण होने का संदेह करती है
# 200  तव उस महाबाहू ने जनकपुत्री को प्रणाम किया, पर वह भय से डरी हुई फिर उसकी ओर नहीं देखती भई
# 200  यदि तू छल करके छलिया राषण फिर मुझे सन्ताप उत्पन्न करता है तो यह अच्छा नहीं
# 200  ऐसी बुद्धि करके वह तनुमध्यया जनकसनया सीता (प्रणाम कर)सर वहीं देती भई
# 200  , ३५, ३६ ) हनुमान मोर सीता का सम्बाद। सीता के वचन को सुनकर भयङ्कर पराक्रम वाला इनुपान् हाथ जो हुए माथे पर रखकर यह उत्तर वाक्य बोला
# 225  राम सदा चिन्तापरायण है, सदा शोकपरायण है, काम के वश पड़ा हुआ यह कुछ और नहीं सोचता है 114
# 225  पूर्णचन्द्रतुल्य मुखबाली मीता यह वचन सुनकर हनुमान से धर्म अर्थ युक्त वचन बोली
# 225  हे धानर विप मिला अमृत तूने कहा है, कि राम का मन किसी दूसरी ओर नहीं, (यह अमृत).मुन्दर काय भौर कि शोकपरायण है (यह विष है )
# 225  देव निःसन्देह रोका नहीं जासक्ता, राम लक्ष्मण और मुझको विपत्तियों से मोहित हुआ देख
# 225  उसके भाई विभीषण ने मेरे कापिस देने के लिये बहुत यत्न किया, पर रावण यह बुद्धि नहीं करता है
# 225  ऐ धानर श्रेष्ट मुझे आशा है मुझे पति जल्दी माप्त होगा, क्योंकि पेरा अनवरात्मा शुद्ध है, और राम में बहुत से गुण हैं
# 225  भानकी वानरश्रेष्ठ से अद्भुत वचन सुनकर इर्ष से पुलाकित सारे अगली इनुपान से बोली ।। १२ । हे वानरोचम मैं पति की पति का आदर करके राम के बिना किसी के शरीर को स्वतः स्पर्श करना नहीं चाहती
# 225  -४०) सीता फे राम को लन्देश यह सुनकर उस बात ये सन्तुष्ट हुआ वाक्य निपुण वानर श्रेष्ठ सीता से यह वाक्य पोका ।। १
# 225  हे देवि यह तेरा उस महात्मा की पत्नी होने के सटमा वचन है,कौन तेरे बिना हे देवि ऐसा वचन का सकी है३
# 225  राम मुझसे यह सब पूरा २ सुनेंगे, अब मुझे कोई आभिज्ञान दे, जिसको राम पहचान लें या तब वस्त्र के नीचे से सुन्दर दिव्य चूड़ामणि (शिरोमणि) खोलकर "यह राम को देना" ऐसा करती हुई सीता ने हनुमान को दिया ।। ५
# 250  और जेसे यह महायाह राम इस दुखि समुद्र से मुझे पार करे, वैसा ठीक २ करना
# 250  यह मेरा सीत्र शोक का वेग, इन राक्षसों से झिड़कें यह सम के समीप जाकर कहो, हे मानरश्रेष्ठ तेरा मार्ग शुभ हो
# 250  इसको विध्वंस करूंगा, जैसे सूखे धन को शामि, इसके नष्ट होने पर रावण कोष करेगा ।। ७
# 250  तब हनुमान ने उस प्रमदाधन को तोड़ना आरम्भ किया, जिसमें मस्त पंछी बोल रहे थे, और अनेक वेळ यूटों से युक्त था
# 250  तव विकृत सुखों पाली * यहां से भागे जो हनुमान के साथ युर दिखलाया है, उसमें अत्युक्ति अवश्य है। सम्भव है, कि हनुमान ने राक्षसों से इन्दयुत मांगा हो। इन युद्ध में एक के सामने एक ही खड़ा होता था, उसके हार जाने पर दूसरा सामने होसका था । रामसियें रावण के पास जाकर एक अयङ्कार विरुप चानर का आना उसे पतलाती भैई ।। २.०
# 250  उस क्रूर रूपवाले को क्रूर दण्ट की आप आज्ञा देने योग्य हैं, जिसने सीता से सम्भापण किया और धन को नाश किया है
# 250  वह बाहर की डेउद्दी पर खड़े हुए उस वानर के पास पहुंचकर इसतरह उस पर टूट पड़े,भिसवरह पतिङ्गे आदि पर
# 250  मुद्दर पट्टिा ,शूल और तोमर हाथों में लिए वह राक्षस सहसा हनुमान को घरकर उसके आगे खड़े होगए
# 250  उन शूरवीरों से चारों ओर से पिरे हुए उस महाबली ने वाइरीद्वार के पास स्थित लोहे का एक परिष (मूल) उठा लिया
# 250  पवनपुत्र वीर उन किंकरों को मार कर वह महावीर युद्ध चाहता हुआ देउदी पर स्थित रहा
# 275  तब डेउढ़ी के पिट पर स्थित सस महाचानर को महातेजस्वी जम्बूमाली ने तीक्ष्ण तारों से घि दिया
# 275  बड़े वेगवाले जस मबल बानर ने घुपाकर उस मूसल को जम्यूमाली की छाती पर मारा
# 275  वेग से ताड़ना किया हुआ वह महारथी जम्बूपाली अङ्गों के चूर २ होजाने से वृक्ष की तरह भूमि पर गिरा ।। ६ ।। जम्बूमाली और महावली किंकरों को हत हुआ पून कर रावण क्रोध से भरगया, और उनके नेश लाल होगये।
# 275  सब उस राक्षसेन्द्र से परे हुए अनितुल्प कान्तिवाले सात मन्धीपुत्र अस भवन से निकले
# 275  तब वह बीर वानर सन सेनापत्तियों को सेना और चाइनों समेत मारकर मजा के नाश में काल की तरह देखड़ी पर उत्सव मनावा भया ।।२३।। उन पांच सेनापतियों को अनुघरों और वाहनों समेत मारा गया सुनकर राजा ने युद्ध के लिये तय्यार सामने खड़े हुए कुमार अक्ष को आज्ञा दी
# 275  पितृ तुल्य पराक्रम वाले उस वानर ने उमको धिकर और जैसे गरुड़ बहे सर्प को उठाता है, इस तरह उठाकर बेग से पृथिवी पर पटका
# 275  उसकी भुजा, राने, कमर और छाती टूट गई, रुधिर बहने लगा, दलियां चूर २ होगई जोड़ और बन्धन टूट गये, ऐसा उस पवनपुत्र ने राक्षस को शयिती पर मार पटका ।। १७ ।। मग २५ (प०४८-४२ ) मेघनाद से युद्ध हनुमान का बन्धना और रावण के दर्शन जय हनुमान ने कुमार अक्ष को मार दिया, तब महात्मा राक्षसपति ने मन को एकाग्र करके देवतुल्य इन्द्रजित (मेघनाद) को आज्ञा दी ।। १
# 275  पद्मतुल्प विशाल नेत्रोंशाला, राक्षसाधिपति महातवा श्री मान पर्व में समुद्र की तरह बाहर निकाला
# 275  रथ पर चढ़कर आते हुए पूर्ण इन्द्र ध्वजवाले को देखकर वानर महानाद करता हुआ गर्मा, और फूल गया
# 275  तच राक्षस द्वारा उस अस्त्र से बांधा हुआ वानर निश्चष्ट होगया, और पृथिवी पर गिर पड़ा
# 300  उस महा हृदय वाले रावण को देखकर महान हृदय वाला धानरश्रेष्ठ सावधान हो अर्थ युक्त वाक्य घोला
# 300  में सुग्रीव के सन्देश से यहां तेरे पास आया हूं, हे राक्षसपति तेरे भाई पानर पति ने तुझे कुमाल कहा है
# 300  जन स्थान का वध तथा पाली का वध जानकर और राम सुग्रीव की मित्रता जानकर अपना हित समझ
# 300  संग२७०५२,५३)हनुमाह की पूछ को आग लगाकर लंकामें घुमाना * महात्मा वानर के वचन को सुनकर क्रोध से मूछिताए रावण ने उसके वध की आजादी
# 300 शापर विभीषण ने इस में अनुमान . * यहाँसे आग लंका दाह का ओ प्रकरण है, इसमें बहुत ही भत्युकि प्रतीत होती है। यह मसभाक्तिी , कि प्रयल राक्षसों की राजधानी में अफेला हनुमान लोगों के घरों में फिर २ कर समको जलाता फिरे,और पकड़ा न जाए । विच बनुमान ने जो उसके प्रबल थोशामों का पता लगामा माहा था, अब इन्द्र गुग से मिस नहीं दी, क्योंकि (हनुमान् ) अपना दूत होना बतला चुका था
# 300 (उसने कहा ) इम वानर को मारना हे राजन् ! यह धर्मविरुद्ध है, छोक बर्ताव से निन्दित है, और तेरे असहमा है।
# 300 उस महात्मा के बचन को सुनकर रावण भाई को देश काल के योग्य उत्तर वाक्य बोला
# 300  पूछ बानरों का प्यारा भूषण होता है, वह इसकी जल्दी प्रदीप्त करो सच यह उस जली हुई के साथ जाए
# 300  उसके वचन को सुनकर क्रोध से प्रचण्ड राक्षस पुराने चुफा था। अब इसकी भी मावश्यकता म थी । हनुमान चामर न था, किन्तु दूसरी जातियों के मुकाबिले में यह उस जाति का नाम या। इसलिये पूंछ का होना ही असंभव है, क्या फिर उसको आग लगाना । संभव यह है, कि रावण ने दूत होने से घजुमार को माय जान फर छोड़ दिया,पर जो हनुमान ने वानरराज सुग्रीव की चढ़ाई की धमकी दी थी, उसके बदले में हनुमान के सन्मुच वानर की पूंछ बनाकर जलाई गई, और इस तरह पर उस वानर जाति पर उपहास किया गया । जैसर कि अब रूस की आकति रीछ बनाते हैं। हनुमान जब जेला भया, तो उसने इस जात्यपमान का बदला यह लिया, कि वानर की पूंछ से ही थे मालूम किले को भागे लगाई; यह जितलाते हुए कि बानर की पंछ हो' तुम्हारे किलों को भस्मसात् करेगी । यह अभिप्राय इतने बड़े मलकार में प्रकट किया है । वस्तुतः न हनुमान की पूंछ थी, न इससे एम २ कर एफ २ घर जलाया, किन्तु एक ही जगह भाग लगाई उस माग से पचन द्वारा फैलकर बहुत बड़ी हानि हुई।मुन्दर का कपासी कपड़ों से उसकी पूंछ को लपेटते भए
# 300  तब गूढ अभिप्राय वाले बड़े दिलवाले, उस महाबानर वानरश्रेष्ठ को पकड़कर राक्षस बहुत हर्षित हुए चले
# 325  यह सोच जलती हुई पुशवाला विजलीवाले मेघके तुल्य बह महावानर लङ्कर के भवनों की चोटियों पर मा४
# 325  राक्षसों के घर से घर और घरों के बगीचों को देखता हुआ यह बानर निडर हो पालों पर घूमा
# 325  घूमते हुए महातेजस्वी पानरश्रेष्ठ में विपीपण के घर को छोड़कर अपने मव दाह कर दिये
# 325  तद बद्द वीयवान सब के घरों को उलांध कर राक्षसन्द्र रावण के पहल पर पहुंचा, तब नाना रवों से भूषित मेरु मन्दर के तुल्य, नाना मङ्गलों से शोभित, उस मुख्पगृह मेंसन १९)
# 325  बह महातेजस्वी बन को तोड़कर युद्ध में राक्षसों को मारकर भयंकर कंकापुरी को दग्धकर शोभायमान हुबा
# 325  सारी लंका को पीड़ित करके उस वानरश्रेष्ठ ने पूंछ के अग्नि की समुद्र में जाकर बुझायः
# 325  व०५७) हनुमान का जाम्यवान आदि के पास वापिसजामा बहे नाद से गर्जना हुआ मेघ की ध्वनि तुल्य ध्वनि डाला वह पहातेजस्वी प्रवर राक्षसों को मारकर अपना नाम विख्यात करके, नगरी को व्याकुल करके, रावण को तग करके, बड़े वीरों को पीड़ित करके, और सीता को अभिवादन करके फिर समुद्र . के मध्य से पर्वतेन्द्र मैनाक को छूकर आया
# 325  घानरश्रेष्ठ ाम्यवान् अतीव मसम्म हुभा उन सब वानरों को बुलाकर यह वचन बोला
# 325  हनुमान् सर्वथा कृतकार्य होकर आया है, इसमें संधाय नहीं, कार्य को किये बिना उसकी ऐमी गर्ज नहीं होसक्ती ।। प्रसन हुए सपी वानर हनुमान को देखन की इच्छा से पर्वत की ऊंचाई से दूसरी ऊंचाई पर और चोटी से दूसरी चोटी पर पहुंचे
# 325  तब वह प्रसन्न मन हुए सभी वादाश्रेष्ठ महात्मा हुनुपान को घेर कर चारों ओर बैठ गये
# 350   आदरणीय पराक्रमी उन दोनों (अद्रद, जाम्बवान) से आहत हुआ और वानरों से प्रसन्न किया हुआ सीता दर्शन की सारी कथा संक्षेष से सुनाता मया
# 350  को मधुवन नामी पगीचा सुग्रीच का रक्षित या, और (मुग्रीव के मामा) महावीर दधिमुख वानर से पालित था ।। ३
# 350  तब उन्होंने विचित्र पनों वाले पलवण पर्वत पर पहुंचकर महाबली राम और लक्ष्मण को सिर से प्रणाम करके
# 350  और युवराज अङ्गद को भागे करके सुग्रीव का अभिवादन कर सीता का समाचार कहना प्रारम्भ किया
# 350  दिव्य मुनहरी मार्ग जो अपने तेम से दीप्त होरही थी, यह राम को दे करके हनुमान् हाप जोड़कर कहने लगा
# 350  सब मैंने देवी से सम्भाषण किया, और सारी बातें सुनाई, बह राम सुग्रीव की मैत्री . को मुनकर दर्ष को प्राप्त भई
# 350  यह शोभा बाली समुद्रिय माण उसने दी है, हे निष्पाप ! तेरे दर्शन के तुल्य इस (आपकी दी मणि) के दर्शन करके दुःख में आनन्द मनाऊंगी
# 350  है दवारय सुत मैं (वर्तमान दावें महीने के पीछे) महीना भर और नीवन धारण करूंगी, महीने के पीछे राक्षसों के बस में पड़ी जीती नहीं७०.६  रहूंगी
# 350  हनुमान से ऐसे कहा हुआ, दशरथमृत उस माणि को हृदय पर रखकर लक्ष्मण समेत पहुत रोया
# 350  उस मणिश्रेष्ठ को देखकर शोक से दुर्वक राम आंसू भरे नेत्रों से सुग्रीव से यह बोला
# 375  इस से बढ़कर क्या दु:ख होगा, जबकि इस समुद्रिय माण को सीता के बिना माया देखता है
# 375  मुझे भी उसी जगह के चल जहां मेरी प्यारी देखी है, उसका समाचार पाकर मैं क्षण भी नहीं ठहर सक्ता हूँ
# 375  इति श्रीमद्वारमीकि रामायणे पुन्दरकाण्ड समासम् ।युद्धकाण्ड-लङ्काकाण्ड युडकाण्ड-लङ्काकाण्ड घ० १,२) हनुमान को पुरस्कार और सेना समेत पफ साय समुद्र पार होने का प्रस्ताव श्रुत्वा हनूमतो वाक्यं यथाचदभिभाषितम् । रामः प्रीतिसयायुक्तो काक्यमुत्तरमब्रवीत्
# 375  एप सबस्वभूतम्त परियङ्गो हनूमतः | मया कालमियं पाप्प दचस्तस्य महात्मनाः
# 375  इत्युक्त्वा पीतिहष्टाङ्गो रामस्त परिपस्वने । हनूमन्तं कृतात्मानं कृतवाक्यमुपागतम्
# 375  कथं नाम समुद्रस्य दुष्पारस्य महाम्भसः । हरयो दक्षिणं पार गमिष्यन्ति समागताः
# 375  इमे शुसः समर्थाश्च सर्वतो हरियूथपाः । समिया) कृतोत्साहा प्रवेष्टमपि पायकम्
# 375  हनुमान ने भूमि में दुर्बम महतं बड़ा कार्य किया है, जो किसी दूसरे से पृथिवीतल पर मन से भी करना अवाक्य है ।। २ ।। किन्तु इस दीन अवस्था में यह बात मेरे मन को बहुत ही चुभती है, कि मैं इस प्रिय करनेवाले के साश मिय नहीं कर सकता हूं
# 375 हां इस समय प्रेम से गले मिलना यही अपना सर्वस्व इम तुमान् महात्मा को देता हूं
# 375  सीता का हूदना तो बड़ी अच्छी तरह होचुका, पर समुद्र को पाकर फिर मेरा मन डिगा जाता है
# 400  यह शूरवीर समर्य, वानर सेनापति सब के सब आपका पिय करने के लिय अनि में भी प्रवेश करने का उत्साह रखते हैं (तब समुद्र का पार होना कौन बड़ी बात है )
# 400  राघवस्य वचः श्रुत्वा मुत्रीचो वाहिनीपतिः ! म्यादिदेश महावीर्यों वानरावानरर्षभा
# 400  पुरस्तात्पभो नीको वीर कुमुद एव च । पन्धान बोधयन्ति स्म वानरैतुभिः सह
# 400  मध्ये तु राजा मुग्रीनो रायो लक्ष्मण एव च । बलिमिहुभिर्धामतः शानियईणः
# 400  ततः पादपसंवा नानाबनसमायुतम् । सपर्वतमासाद बानरास्ते समारुहन्
# 400  महेन्द्रपथ अमाप समो राजीवलोचनः । आरुरोह महाबाहुः शिखरं दुमभूपितम्
# 400  वां सेना समुस्मृज्य मा च कश्विस्कृतो बजे । गच्छन्तु वानराः शूगर हेच छ भयं च नः
# 400  विरान समीपस्य सागरस्य च तलम् । मधुपाण्डमला श्रीमान्द्रितीय र सागर
# 400  इसन्तमिव फेनधिस्यन्त.श्रीवारमीकि रामायण मिव चोमिभिः । चन्द्रोदय समुद्भूतं प्रतिचन्द्रसमाकुलम्
# 400  सागर चाम्बरमख्यमम्वरं सागरोपमम् । सागरं चाम्बरं चेति निर्षिघोषमापत
# 425  आगे २ वीर ऋषभ नील और कुमुद यह और बहुत से घानरों के साथ मार्ग को शोधने जारहे थे
# 425  सब वृक्षों से भरे हुए नाना बनों से युक्त सह पर्वत को पाकर वर वानर उप्त पर चढ़ गए
# 425  उसके पीछे महाबाहु कमलनेत्र राम महेन्द्र पर पहुंचकर वृक्षों से भूषित उसके शिखर पर चढ़े
# 425  शिखर पर चढ़कर दशरथसुत राम ने कूर्म मछलियों से पूर्ण समुद्र के दर्शन किये
# 425  का सब महापर्वत सह्य और मलय को उलांधकर क्रमाा भयङ्कर ध्वनिवाले समुद्र पर पहुँचे । १२
# 425  अब समुद्र से उठे जल प्रवाहों से धोई हुई शिलाओं वाले विशाक किनारे पर पहुंचकर राम यह वचन बोके
# 425  सो यहां ही छावनी डालिए, और विचार कीजिये, जिससे कि यह पानर सेना परले पार पहुंच जाए
# 425  राम के वचन को सुनकर सुग्रीव और लक्ष्मण ने वृक्षों से भरे हुए सागर तीर पर सेना की छावनी डालदी
# 425 समुद्र आकाशके समान और आकाा समुद्र के समान होने से समुद्र और आकाश निर्विशेष (एक से) दीयते थे
# 425  (भमुद्र का) मा आकाश के (प्रतिविम्ब ) से मिला हुआ, और आकाश (ऊंची लहरों के) जह से मिला हुआ, इसपकार दोनों बारे और रत्नों से भरे हुए एक से रूपकाले दीखते थे
# 450  सक्षसेन्द्र में ऐसे को हुए महावली रासस हाथ जोड़कर राक्षमेन्द्र रावण से बोले ।।। हमारा यल - (सेना) बहुत बड़ा है, आप क्यों एदास होते हैं, आपने भोगवती में माकर नाग जीते हैं।
# 450  याप यक्षों के समूहों को गिराकर दिकाकर और जीतफर कैलास की चोटी से विमान लाए
# 450 हे राजन् यह एक प्राकृतमान के अनुचित विपत्ति भाप मन में न रखें, आप सब को मारेंगे
# 450  प्रमादी और दैव से मारे हुए पानुओं में पराक्रम फलते हैं, जब परीक्षा करके विधि से कमाए गए हों
# 450  विभीषण के वचन को पुनकर राक्षसेश्वर रावण उन सब को विसर्जन करके अपने घर में प्रविष्ट हुभा
# 450  राक्षसी से पूजित उस महावाहू ने अपने वज से दीप्यमान, आसन पर बैठे हुए, रावण को प्रणाम किया
# 450  और एकान्त मे मन्त्रियों के समक्ष उसने महात्मा रावण को हेतुओं से निश्चित अतीव हितकारी वचन कहा
# 450  इस गम्भीर अर्थवाले नर्म हेतुओं से युक्त भूत भविष्यत और वर्षमान में फलप्रद हित वचन को मुनकर विषयासक्त गवण ने सन्तत होकर यह एचर दिया
# 450  किमी से मय नहीं देखता हूं, राम कमी सीता को नहीं पाएगा, युद्ध में इन्द्र सहित देवताओं के साथ भी गम मेरे आगे कैसे खड़ा होगा ।। १४ ।। यह कहकर देवताओं की सेना के नाम करनेवाले रण में प्रचण्ड पराक्रमवाले महावली रावणने सत्यवादी माई विभीषण को विसर्जन किया
# 450  अब समय बीत जाने पर रावण युद्ध में मन्त्री और मुहदों के साथ सलाह का समय समझता मया
# 475  यह सुवर्ण की जालियों चाले मणि और गुलियों से भूपित सिधे हुए घोड़ों वाले महारथ पर पाकर सवार हुआ
# 475  बड़े मेघ के तुल्य ध्वनिमाले उस रथ पर चढ़ कर वह राक्षसश्रेध रावण सभा की ओर गया
# 475  और नाना प्रकार के अलग २ चेपा वाले नाना भूषणों से भूपित्त रोधे पावों से और पीछे से घेर कर चले
# 475  तब महात्मा विभीपण सोने से विचित्रित अङ्गों वाले उत्तम घोड़ों पाले शुम स्थ पर चढ़कर बड़े भाई की सभा को गया ।युद्धकाण्ड-लङ्काकाण्ड समै ६ (२०१३) राज सभा में राजा श्रीर मरिषयों का विचार । वह रणों के जीतनेवाला, उम भरी सभा की ओर देखकर सेनापाई महस्त को आज्ञा देता मया
# 475  तब सारी सेना को नगर की रक्षा के लिये अलग २ लगाकर महस्व राजा के सामने बैठाया और बोला
# 475  सीता देनी नहीं है, और दशरथ के दोनों पुत्रों को मारना है, यह सोच कर आप विचार कीजिये और मुनीति युक्त कहिये
# 475  कामके बस हुए (रावण) के रोने को सुनकर कुम्भकर्ण क्रुद्ध हुआ और यह वचन बोला
# 475 हे महाराज ! यह सब पापका अतुल काम है, इस काम की सलाइ आरम्भ में ही हमारे साथ करनी थीं
# 475  रावण को क्रुद्ध जानकर महावली महापाय थोड़ी देर सोचकर क्षाथ जोड़कर बोला
# 475  सो हे महावल यहां आए श्रापके सारे शत्रुओं को हमशन के प्रताप से बस में करेंगे
# 500  सगै ७ (२०५४) विभीषण को सीता को वापिस देने की सम्मति। रामसेन्द्र के रचन को और कुम्भक की गर्जनाओं को सुनकर विभीषण राक्षसराज का हितकारी गम्भीर तात्पर्य वाला मुख्य वचन बोला
# 500  विभाषण के वाक्य को सुनकर प्रास्त बोला, इम न देवताओं से न दानापों से कभी भय समझते हैं
# 500  सहस्त के अहित चाक्य को सुनकर राजा का हित चाइनेवाला धर्म अर्थ काम में स्चिन बुदिशाका विभीषण बड़े अर्थवाला बचन बोला
# 500  धर्म प्रधान, महाराथी, दक्ष्वाकुवंश में उत्पन्न हुए, अपने कार्यों में शक्तिमान राजा राम के सामने देवता भी मूढ़ हो जाते हैं ।। ८
# 500  यह राजा न्यसनों के घर में हुभा स्वभाव से ही तीक्ष्ण और पिन साँचे करने वाला है, तिस पर शत्रु तुल्य आप जैसे मित्र राक्षसों के नाशार्थ से सलाह दे रहे हैं ।।२।। यह इस पुर के सथा सुहृद' जनों और दूसरे राक्षसों समेत रामा के लिये पथ्य ठीक पचन जो अपना मत है, कहता हूँ, वह यह कि सीता नरेन्द्रपुत्र को दे दीजिये
# 500  शत्रु का बल, और अपना बल, देवाकाल,क्षय और धदि यह सब चातें धुद्धि से सोचकर जो स्वामी का हित याम्य वाक्य कहे, वही मन्त्री है
# 500  इस कुल में एकही पुरुष सत्व, वीर्य, पराक्रम, धैर्य, शौर्य, और तेज से हीन हुआ है, और यह या छोटा सात विभीषण है
# 500  तत्र इन्द्रसरका दुर्जेय बढ़े पराक्रमी के वचन को सुनकर शानधारियों में श्रेष्ठ विधीपण बड़े अर्थवाला वचन बोला
# 500  हे राजन् ! इस धन, रत्न, भूषण, दिव्य बच्च, विचित्र पनि और देवी सीता राम को अर्पण करके यहां बीतशोक हुए धसे ।। ६
# 500 “युद्धकाण्ड-लङ्काकाण्ड • +नागिन न्यानि दाखाणि न ना पाषा भयावहाघोरा स्वार्थमयुक्तास्तु शातयो नो भयावदाः
# 525  इत्युक्तः परुष वाक्य न्यायवादी विभीषणः । उत्पपारा गदापाणिश्चतुभि सह राक्षसः
# 525  निवार्षमाणस्य मया हिवैपिणा न रोचते ते वचनं निशाचर । परान्तकाले हि साधुपो नरा हितं न गृहन्ति मुहगिरीरितम्
# 525  ऐसे कठोर वचन कहा हुआ न्यायवादी विभीषण गदा हाथ में लिये चार रासों सहित उठ खड़ा हुआ
# 525  और क्रुद्ध हुभा विभीषण यह वाक्य घोला, तू भूला हुआ है हे राजन् ! कहो . मुझे जो २ कुछ चाहता है ।। १८
# 525  बड़ा भाई माननीय है, पितृतुल्प है, पर धर्म मार्ग पर स्थित नहीं है। मैं तुझ बड़े भाई के भी इतने कठोर वाक्य को नहीं सइसक्ता है
# 525  हे रावण हितैषी से उत्तम नीति युक्त कहे चाक्य को काल के बस में हए अजितेन्द्रिय पुरुष स्वीकार नहीं करते हैं ।। २०
# 525  आप बड़े हैं, क्षमा कीजिये, ओ आपका हित चाहते हुए, मैंने कहा है ।। २२
# 525  सर्वधा अपनी और राक्षसों समेत इस पुरी की रक्षाकर, आपको स्वस्ति हो, मैं जाउंगा, आप मेरे बिना सुख से रहें
# 525  मैं हितैषी होकर रोकता है,हे राक्षस आपको मेरा वचन पसन्द नहीं आता है, दूर हुई पाचु दा पुरुप अन्तकाल के आने पर प्रहदों से कहे हित वाक्य को ग्रहण नहीं करते हैं
# 525 युद्धकाण्ड-ठङ्काकाण्ड संगै ९ (व० १७,१८) विभीषण का रामकी शरण श्राना। . रावण का छोटा भाई रावण को यह कठोर वचन कहकर बहुत जल्दी वहाँ आया, जहां लक्ष्मण सहित राम थे
# 550  यह (बड़ा भाई) जनस्थान से जटायु को मारकर सीता को हरलाया है, वह दीन वेवस हुई वहाँ रुकी है, और राक्षसियों से सुरक्षित है
# 550  उलटा उसने मुझे कटोर कहा, और दास की तरह अपमानित किया, सो मैं स्त्री पुत्रों को छोड़कर सघन की शरण आया हूं
# 550  अब सारे लोगों को शारण देनेवाले महात्मा राघर को जल्दी बतलायो, कि विभीषण आया है
# 550  रावणका छोटा भाई विभीषण चार दूसरे राक्षसों सहित आपकी शरण आया है
# 550 (मैं जानता हूं) रावण से भेजा हुआ, माया से ढका हुआ, कुटिल बुद्धि से यहां आया है, कि आपके विश्वस्त होने पर आप पर प्रहार करे
# 550  मित्रभाव में प्रात हुए को मैं कभी स्वाग नहीं सक्का यद्यपि उसका दोष हो, पर पलों से यह (शरणागत का त्याग) निन्दित है
# 550  चाहे यह निशार दुष्ट हो, वा अदुष्ट हो, पर ऐसे दुःख में जो भाई को त्याग सक्ता है
# 550  उसके लिये कौन हो संक्ता है, जिसको यह न त्यागेगा
# 550  न वर्षे तत्कुनिाश्च राध्यकाली चराक्षम पण्डिवा दि भविष्यन्ति तस्माद् अायो विभीषणः
# 550  +आतों या याद वा सः परेषां शरणं गतः। भरिमाणान्परिखज्य रक्षितम्या कृतात्पना
# 575 .श्रीवास्मीकि रामायण टीका-वानराधिपति के वचन को सुनकर, और सब की ओर देखकर सो पराकमवाला राय यह वाक्य बोला
# 575  शत्रु उस कुल के और साथ वाले देश के होते हैं, जोकि व्यसनों में प्रहार किया करते हैं, इसलिये यह यहां आया है
# 575  इस उसकी कुल के नहीं हैं, और विभीषण राज्याभिलाची है, यई लोग समझदार होवे है (भाई के विनाश में इसे राज्य मिलता है हमारे विनाका में नहीं) इसलिए. विभीरण ग्राह्य है,
# 575  इसमकार शरणागत की रक्षा न करना । घड़ा दोष है, स्वर्ग और यश का विरोधी और घल बीर्य का नाशक है
# 575  एकबार ही जो "मैं तेरा ह" ऐसी याचना करता हुआ शरणागत हुआ है, ऐमें सब लोगों को मैं अभय देता है, यह मेरा ब्रत है
# 575  मेरा भी अन्तरात्मा विभीषण को शुद्ध जानता है अनुमान से और हृदय के भाव से सब तरह सुपरीक्षित है
# 575  सगै १९ (व. २९ ) विभीषण का शरणागत होना राम से अभय दिये जाने पर झुका हुपा रावण का छोटा भाई चारों राक्षसों ममेत पाओं पर आ गिरा
# 575  सब विभीपण ने राम के प्रति यह वाक्य कहा, में रावण का छोटा भाई हूँ उससे अपमानित हुआ हूं
# 575  आप जोकि सब लोगों के शरण लेने योग्य हैं, उनकी शरण पड़ा हूं, मैंने लवन मित्र और धन सब छोड़ दिये है
# 575  आपके अधीन मेरा राज्य जीवित और सुख है । उसके इस वचन को सुनकर वाणी से उसकोवसल्ली देकर और नेत्रों से मानों पीते हुए राम यह वचन बोले, मुझे राक्षसों का बलाचळ ठीक २ को
# 600  महोदर, महापार्थ और अकम्पन राक्षस यह युद्ध में लोकपालों के तुल्य उसके सेनानी हैं
# 600  रावण रसातल वा पाताल में प्रवेश कर । जाए, अथवा ब्रह्मा के पास चला जाए, पर अब मुझ से यह जीता । नहीं छुटेगा ।। १५ ।। मुखदायी कर्मावाले राम के वचन को सुन कर वह धर्मात्मा सिर से पन्दना करके फिर कहने लगा
# 600  वह पर्ववतुल्प वानरश्रेष्ठ पर्वतों से वृक्षों को तोड़कर समुद्र की ओर खींच लाये
# 600  और वह महावली महाकाय वानर हाथी जितने बड़े २ पत्थरों को और पर्वतों को यन्त्रों से उखाड़कर ढोते भए
# 600  फैकी जाती हुई शिलाओं और गिरते हुए पर्वतों का उस महासागर में तुमल शब्द होता था
# 600  इसमकार नल से बनाया, मगरों के घर समुद्र पर वह पुल आकाश में स्वातीपथ की तरह सुन्दर मुहापना शोमा पाव भया
# 600  अब धर्मात्मा श्रीमान् राम धनुष धारे हुए लक्ष्मण और सुग्रीव के साथ उस सेना के आगे २ चले
# 600  समुद्र से पार उतरती हुई वानर सेना महा ध्वनि से समुद्र की गम्भीर भयङ्कर धनि को दांप लेती भयी
# 600  राम के उस अदभुत दुष्कर फर्म को देख सिद्ध और चारणों सहित देवता और महर्षि राम के पास मा शुभजलों से उसे अलग २ अभिषेक करते भये
# 600 हे नरदेव सागर समेत सारी पृथिवी को जीत, और अनेक वर्ष उसे पालन कर, इमप्रकार वह विविध भवचनों से मनुष्य और देवताओं से संस्कृत राम को पूजते भये
# 625  तुम दानों बेमालुम वानरों की सेना में प्रवेश करके सेना का परिमाण और मुख्य २ वानर-१३
# 625 जो युद्ध में आगे लगने वाले है, और जो दूसरे शूरवीर वानर है, और जैसे उन महात्मा वानरों का निवेश (तरतीव) है ।। ४ । और राम का और वीर लक्ष्मण का व्यवसाय पाक्ति और शव ठीक २ जानने योग्य हो
# 625  ऐसे आया दिये हुए शुक धौर सारण राक्षस चीर वानरों का रूप धारणकर वानरों की सेना में प्रविष्ट हुए
# 625  ढके हुए उन दोनों शुक सारण को विभीषण ने देख लिया, और राम को पचलाया
# 625  शत्रुओं के किलों को जीतने वाले ! यह राक्षपेन्द्र के मन्त्रीशुक और सारण गुप्तचर होकर लङ्का में आए हैं
# 625  वह दोनों राम को देखकर दुखित हो, और जीवित में निराश हो, हाथ बांधे रस्ते हुए यह वचन बोले
# 625  और यदि कुछ देखना रहगया हो, तो वह सारा देखलो, अघवा विभीषण ही तुमें सब कुछ दिखला देगा ।। ६४ पकड़ा जाने पर तुम्हें अपने जीवन के विषय में डर नहीं होना चाहिये, क्योंकि शव छोड़े हुए दत वध के योग्य नर्स होते हैं
# 625  कल सवेरे कोट और डेवाड़यों समेत का और राक्षसों की सेना को मेरे चाणों से नष्ट होता हुआ तू देखेगा
# 625  इस मकार सन्देश दिये हुए शुक सारण राक्षस "भय हो" इस प्रकार धर्मप्रिय राघव को प्रविनन्दन करके
# 625  यह कहकर शुक और सारण को लज्जित हुए और जय शब्द कहकर बाहर चले गये देखकर
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-198-dccb7bfddf8f> in <module>
# ----> 1 df2 = alternate_summarization(text_sentence)
#
# <ipython-input-197-d601b8f32eca> in alternate_summarization(text_sentence)
#      13         startflag +=25
#      14         endflag +=25
# ---> 15     return pd.DataFrame(parsed_text)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     390                                  dtype=dtype, copy=copy)
#     391         elif isinstance(data, dict):
# --> 392             mgr = init_dict(data, index, columns, dtype=dtype)
#     393         elif isinstance(data, ma.MaskedArray):
#     394             import numpy.ma.mrecords as mrecords
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     210         arrays = [data[k] for k in keys]
#     211
# --> 212     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     213
#     214
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      49     # figure out the index, if necessary
#      50     if index is None:
# ---> 51         index = extract_index(arrays)
#      52     else:
#      53         index = ensure_index(index)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in extract_index(data)
#     315             lengths = list(set(raw_lengths))
#     316             if len(lengths) > 1:
# --> 317                 raise ValueError('arrays must all be same length')
#     318
#     319             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
df2.head()
# Out:
#                                                 text  \
# 0  [ वानर हनुमान सीमा के देखने की उत्कण्ठा येसूया...
# 1  [ वानर हनुमान सीमा के देखने की उत्कण्ठा येसूया...
# 2  [ वानर हनुमान सीमा के देखने की उत्कण्ठा येसूया...
# 3  [ वानर हनुमान सीमा के देखने की उत्कण्ठा येसूया...
# 4  [ वानर हनुमान सीमा के देखने की उत्कण्ठा येसूया...
#
#                                            alt_title
# 0   वानर हनुमान सीमा के देखने की उत्कण्ठा येसूयास...
# 1   उस समय सुन्दर 'सब ओर से सजे हुए श्वेत मेघ के ...
# 2   एक भवन से दूसरे भवन को जाते हुए उस वानरश्रेष्...
# 3   वहाँ राक्षसों के घरों में उसने अप "करते हुओं ...
# 4   तब वह उस सुन्दर पड़ी माला की ओर मस्थित हुआ, ज...

# %%
from flair.data import Sentence
from flair.models import SequenceTagger
# load the model you trained
model = SequenceTagger.load('/Users/rohanraj/Documents/Master/CaseStudy2/code/resources/taggers/netag/best-model.pt')

# create example sentence
#sentence = Sentence('मोहनदास करमचन्द गांधी (२ अक्टूबर १८६९ - ३० जनवरी १९४८) भारत एवं भारतीय स्वतंत्रता आंदोलन के एक प्रमुख राजनैतिक एवं आध्यात्मिक नेता थे।')
sentence = Sentence(df2['alt_title'][0])
# predict tags and print
model.predict(sentence)

print(sentence.to_tagged_string())
# Out:
# 2020-03-01 20:30:15,393 loading file /Users/rohanraj/Documents/Master/CaseStudy2/code/resources/taggers/netag/best-model.pt
# वानर <B-PERSON> हनुमान <B-PERSON> सीमा <B-LOCATION> के <o> देखने <o> की <o> उत्कण्ठा <o> येसूयास्त <B-PERSON> की <o> प्रतीक्षा <o> करता <o> भया <o>

# %%
from flair.data import Sentence
from flair.models import SequenceTagger
# load the model you trained
model = SequenceTagger.load('/Users/rohanraj/Documents/Master/CaseStudy2/code/resources/taggers/netag/best-model.pt')

# create example sentence
#sentence = Sentence('मोहनदास करमचन्द गांधी (२ अक्टूबर १८६९ - ३० जनवरी १९४८) भारत एवं भारतीय स्वतंत्रता आंदोलन के एक प्रमुख राजनैतिक एवं आध्यात्मिक नेता थे।')
sentence = Sentence(df['title'][0])
# predict tags and print
model.predict(sentence)

print(sentence.to_tagged_string())
# Out:
# 2020-03-01 20:29:04,306 loading file /Users/rohanraj/Documents/Master/CaseStudy2/code/resources/taggers/netag/best-model.pt
# घ४-९) <o> सीता <B-PERSON> को <B-PERSON> रावण <B-PERSON> के <B-PERSON> भन्तापुर <B-LOCATION> में <B-PERSON> ढूंढना <o> : <o> वह <B-PERSON> महावीर्य <B-PERSON> महान <B-PERSON> हृदय <B-PERSON> पाछा <B-PERSON> वानर <B-PERSON> श्रेष्ठ <B-PERSON> रात <B-PERSON> के <o> समय <o> अद्वार <B-PERSON> से <o> कोट <B-PERSON> को <o> फांद <o> कर <o> का <o> में <o> प्रविष्ट <o> हृया <o>
# उस <o> समय <o> सुन्दर <o> 'सब <B-PERSON> ओर <o> से <o> सजे <o> हुए <o> श्वेत <B-PERSON> मेघ <o> के <o> तुल्य <o> राक्षसों <o> के <o> जो <o> पद्माकार, <o> स्वस्तिकाकार, <o> और <o> वर्धमान <o> घर <o> है, <o> उन <o> से <o> इंका <o> जगमन.
# राक्षसों <B-PERSON> के <o> घर <o> से <o> घर <o> और <o> बगीचों <I-LOCATION> को <o> देखता <o> हुआ <o> बेधड़क <I-LOCATION> यह <o> महलों <I-LOCATION> के <o> पास <o> घूमा <o>
# तब <o> वह <o> उस <o> सुन्दर <B-PERSON> पड़ी <o> माला <I-LOCATION> की <I-LOCATION> ओर <o> मस्थित <B-PERSON> हुआ, <o> जो <B-PERSON> उत्तम <B-LOCATION> स्त्री <B-PERSON> की <B-PERSON> तरह <o> रावण <B-PERSON> की <B-PERSON> बड़ी <o> पारी <o> थी <o>
# में <o> बस <o> वानर <B-PERSON> यूयपति <B-LOCATION> ने <B-PERSON> चन्द्र <B-PERSON> तुल्य <B-LOCATION> मुखवाली, <B-PERSON> सुन्दर <B-PERSON> कुण्डल <o> पहने <o> हुई, <o> ताजे <B-LOCATION> घुषषों <B-PERSON> की <B-LOCATION> पालाएं <B-PERSON> और <o> भूषणोंवाली <B-PERSON> पनियों <o> को <I-LOCATION> देसा <B-LOCATION>

# %%
# Standford nlp is being used for lemmatization

# %%
def lemmatization(text):
    lemmatized_text = []
    for line in tqdm(text):
        if line not in [""," "] :
            doc = nlp(line)
            for sent in doc.sentences:
                for wrd in sent.words:
                    #extract text and lemma
                    lemmatized_text.append(wrd.lemma)
    return lemmatized_text

def remove_stopwords(word_tokenized,stop_words):
    return [word for word in word_tokenized if word not in stop_words]

def custom_remove_garbage(original_words_list,list_of_garbage_words):
    tmp_list = [word for word in original_words_list if word not in list_of_garbage_words] # garbage list
    tmp_list = [word for word in tmp_list if len(re.findall("\d+",word))==0] # english numbers
    tmp_list = [word for word in tmp_list if len(re.findall("[a-zA-Z]+",word))==0] # english alphabets
    return tmp_list

def Diff(li1, li2): 
    li_dif = [i for i in li1 + li2 if i not in li1 or i not in li2] 
    return li_dif

# %% [markdown]
# ## Topic Meddling after prepocessing

# %%
def topic_modelling(text_sentence,stop_words):
    df = pd.DataFrame()
    startflag = 0
    endflag = 25
    for text in range(int(len(text_sentence)/endflag)):
        
        #Clean text after lemmatization
        lemmatized = lemmatization(text_sentence[startflag:endflag])
        clean_text = remove_stopwords(lemmatized,stop_words)
        #len(clean_text),len(lemmatized) #281,612
        
        # remove punctuation from each word
        table = str.maketrans('', '', string.punctuation)
        stripped = [w.translate(table) for w in clean_text]
        #print(stripped[:25])
        #print(len(clean_text),len(stripped)) #281

        resultant = Diff(clean_text,stripped)
        #len(set(resultant)) #19

        final_text = custom_remove_garbage(stripped,resultant)
        #len(final_text) #265
        
        # Create Dictionary
        id2word = corpora.Dictionary([final_text])

        # Create Corpus
        texts = final_text

        # Term Document Frequency
        corpus = [id2word.doc2bow(texts)] 
        
        # Build LDA model

        lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=5, 
                                           random_state=100,
                                           update_every=10,
                                           chunksize=100,
                                           passes=20,
                                           alpha='auto',
                                           per_word_topics=True)
        #pprint(lda_model.print_topics())
        temp_file = datapath("model")
        lda_model.save(temp_file)
        lda = gensim.models.ldamodel.LdaModel.load(temp_file)
        lda.update(corpus)
        lda.save('model')
        temp_df = pd.DataFrame(lda.print_topics())
        df = df.append(temp_df,ignore_index=True) 
        startflag +=25
        endflag +=25
    return df

# %%
df4 = topic_modelling(text_sentence,stop_words)
# Out:
# 100%|██████████| 25/25 [00:02<00:00, 10.40it/s]
# 100%|██████████| 25/25 [00:02<00:00, 10.90it/s]
# 100%|██████████| 25/25 [00:02<00:00, 11.24it/s]
# 100%|██████████| 25/25 [00:02<00:00, 10.24it/s]
# 100%|██████████| 25/25 [00:02<00:00, 10.86it/s]
# 100%|██████████| 25/25 [00:02<00:00, 10.41it/s]
# 100%|██████████| 25/25 [00:02<00:00, 10.38it/s]
# 100%|██████████| 25/25 [00:02<00:00, 10.67it/s]
# 100%|██████████| 25/25 [00:02<00:00, 10.58it/s]
# 100%|██████████| 25/25 [00:02<00:00, 10.50it/s]
# 100%|██████████| 25/25 [00:02<00:00,  9.82it/s]
# 100%|██████████| 25/25 [00:02<00:00,  9.73it/s]
# 100%|██████████| 25/25 [00:02<00:00,  8.61it/s]
# 100%|██████████| 25/25 [00:02<00:00,  9.98it/s]
# 100%|██████████| 25/25 [00:02<00:00, 10.49it/s]
# 100%|██████████| 25/25 [00:02<00:00, 10.90it/s]
# 100%|██████████| 25/25 [00:02<00:00, 10.69it/s]
# 100%|██████████| 25/25 [00:02<00:00,  9.69it/s]
# 100%|██████████| 25/25 [00:02<00:00,  9.37it/s]
# 100%|██████████| 25/25 [00:02<00:00,  9.61it/s]
# 100%|██████████| 25/25 [00:02<00:00,  8.37it/s]
# 100%|██████████| 25/25 [00:02<00:00,  9.89it/s]
# 100%|██████████| 25/25 [00:02<00:00, 10.21it/s]
# 100%|██████████| 25/25 [00:02<00:00,  9.29it/s]
# 100%|██████████| 25/25 [00:02<00:00,  9.22it/s]
# 100%|██████████| 25/25 [00:02<00:00,  9.37it/s]

# %%
df4.shape
# Out:
# (130, 2)

# %%
df4.tail(5)
# Out:
#      0                                                  1
# 125  0  0.005*"सेना" + 0.005*"सारण" + 0.005*"कह" + 0.0...
# 126  1  0.005*"सेना" + 0.005*"सारण" + 0.005*"कह" + 0.0...
# 127  2  0.005*"सेना" + 0.005*"सारण" + 0.005*"कह" + 0.0...
# 128  3  0.005*"सेना" + 0.005*"कह" + 0.005*"सारण" + 0.0...
# 129  4  0.036*"सेना" + 0.029*"सारण" + 0.025*"कह" + 0.0...

# %%
df4.to_csv('combined_model_topic.csv')

# %%
temp_file = datapath("model")
lda = gensim.models.ldamodel.LdaModel.load(temp_file)
